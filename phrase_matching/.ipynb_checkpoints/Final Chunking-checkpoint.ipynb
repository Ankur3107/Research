# %%
import pandas as pd
import spacy
from spacy.matcher import Matcher
from spacy import displacy
import textacy
import re
from tqdm import tqdm
from tqdm import tqdm_gui
import warnings
warnings.filterwarnings('ignore')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
data = pd.read_excel('l1_12_sentiment_modified.xlsx',sheet_name="BusinessDevelopmentSupport")

# %%
def pos_regex_matches(doc, pattern):
    # standardize and transform the regular expression pattern...
    pattern = re.sub(r"\s", "", pattern)
    pattern = re.sub(r"<([A-Z]+)\|([A-Z]+)>", r"( (\1|\2))", pattern)
    pattern = re.sub(r"<([A-Z]+)>", r"( \1)", pattern)

    tags = " " + " ".join(tok.pos_ for tok in doc)

    for m in re.finditer(pattern, tags):
        yield doc[tags[0 : m.start()].count(" ") : tags[0 : m.end()].count(" ")]

# %%
def get_all_noun_chunks(texts, pattern, lemma=False):
    all_results = set()
    for i in tqdm(range(len(texts))):
        text = texts[i]
        if type(text)==str:
            doc = nlp(text)
            lists = pos_regex_matches(doc, pattern)
            for list in lists:
                if lemma:
                    all_results.add(' '.join(['%s' % w.lemma_ for w in list.as_doc()]))
                else:
                    all_results.add(list.text)
    return all_results

# %%
all_adj_noun = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<ADJ>*<NOUN>+')
all_noun = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<NOUN>+')
all_adj_noun_lemma = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<ADJ>*<NOUN>+',lemma=True)
all_noun_lemma = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<NOUN>+',lemma=True)
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 132.13it/s]
# 100%|██████████| 200/200 [00:01<00:00, 136.78it/s]
# 100%|██████████| 200/200 [00:01<00:00, 117.58it/s]
# 100%|██████████| 200/200 [00:01<00:00, 132.93it/s]

# %%
all_adj_noun_lemma
# Out:
# {'account',
#  'account statement',
#  'account statment request',
#  'acitivite',
#  'active account app',
#  'activity',
#  'advantage',
#  'advisor portal',
#  'amc',
#  'amcs',
#  'anything',
#  'app',
#  'application',
#  'application form',
#  'applicationn',
#  'assistence',
#  'aum',
#  'aurangabad',
#  'awareness',
#  'awareness programe',
#  'awerence traning program',
#  'awereness presention',
#  'bad manager',
#  'belgaum branch service',
#  'benefit',
#  'big event',
#  'bikaner branch',
#  'birla',
#  'birla sunlife',
#  'branch',
#  'branch rm visit',
#  'brokerage statment',
#  'bsl',
#  'bsl dividend yield',
#  'bsl equity advantage fund',
#  'bsl equity fund',
#  'bsl frontline equity fund',
#  'bsl mf',
#  'bsl mf partner programe',
#  'bsl office',
#  'bsl tax relief',
#  'bsl trb programe',
#  'bslamc',
#  'bsll',
#  'bslmf',
#  'bslmf end',
#  'bslmf fund',
#  'business',
#  'bussiness improvement',
#  'calculation',
#  'call',
#  'cam',
#  'certification',
#  'cheque',
#  'client',
#  'co -',
#  'colour',
#  'commmon application form',
#  'common application form',
#  'common man',
#  'communication',
#  'company',
#  'conatct',
#  'concall',
#  'conference',
#  'conference call',
#  'conversation',
#  'current economic scenario',
#  'current factsheet',
#  'current market scenario',
#  'customer',
#  'customer sip registration',
#  'daily sms alert',
#  'day',
#  'day ifa',
#  'debt',
#  'debt fund',
#  'dehradhun',
#  'detail',
#  'dhanbad branch',
#  'dinner',
#  'direct face',
#  'dispatch detail',
#  'distributor',
#  'distributor engagement program',
#  'dividend',
#  'dynamic',
#  'easyness dsp blackrock',
#  'education training programme',
#  'elss form',
#  'email',
#  'end',
#  'equity',
#  'equity market',
#  'equity scheme',
#  'event',
#  'everything',
#  'exact explanation',
#  'experience',
#  'facebook',
#  'facility',
#  'fact sheet',
#  'facthsheet',
#  'factsheet',
#  'factsheet anything',
#  'fast sheet',
#  'fatca form',
#  'feedback',
#  'few ifas',
#  'file',
#  'financial gold plan training',
#  'financial planning',
#  'fingo',
#  'fingo partner app',
#  'first part training',
#  'fitness workshop',
#  'food',
#  'form',
#  'form amc',
#  'form form',
#  'format',
#  'frequent training program',
#  'fund',
#  'fund infomration',
#  'fund information',
#  'fund manager',
#  'fund performance',
#  'fund performance information',
#  'fund performance return chart',
#  'fund update',
#  'geeta',
#  'ghaziabad',
#  'gold specialist',
#  'good co - operation',
#  'good experience',
#  'good meeting',
#  'good service',
#  'good support',
#  'good tea',
#  'good training event',
#  'guidance',
#  'gurunath',
#  'handbook',
#  'hard copy',
#  'hard copy fact sheet',
#  'hard copy factsheet',
#  'hardcopy',
#  'hdfc',
#  'hdfc mf',
#  'head',
#  'home address',
#  'icici',
#  'icici mf',
#  'icici suggestion',
#  'idfc people',
#  'ifa',
#  'ifas',
#  'incentive',
#  'information',
#  'initiative',
#  'initmation',
#  'interacation',
#  'interaction meeting',
#  'interesting topic',
#  'internet',
#  'investment',
#  'investment scheme',
#  'investor',
#  'investor education programe',
#  'invitaion',
#  'invitation',
#  'issue',
#  'jammu',
#  'jodhpur',
#  'khammam location',
#  'kim',
#  'kind',
#  'knowledge',
#  'knowledge improvement',
#  'kolhapur',
#  'kyc form',
#  'l',
#  'lack',
#  'last meeting',
#  'load',
#  'lucknow branch office',
#  'mail',
#  'major business',
#  'many other amcs',
#  'mark regard',
#  'market',
#  'market condition',
#  'market crash',
#  'market information',
#  'market update',
#  'marketing update',
#  'meerut',
#  'meeting',
#  'mf house',
#  'minimum redeemption',
#  'mistake',
#  'model',
#  'month',
#  'month factsheet',
#  'monthlty factsheet',
#  'monthly basis',
#  'monthly factsheet',
#  'montly basis',
#  'moradabad',
#  'more awarene programe',
#  'more awareness training',
#  'more business',
#  'more detail',
#  'more equity',
#  'more knowledge',
#  'more training',
#  'more training programme',
#  'motivation',
#  'motivational speaker',
#  'much business',
#  'mumbai',
#  'mutual fund',
#  'nach form',
#  'nagar',
#  'name',
#  'neft',
#  'new change',
#  'new form',
#  'new ifas',
#  'new luanche',
#  'new nfo detail',
#  'new nfo update',
#  'nfo',
#  'nfo form',
#  'nfo meeting',
#  'nice training class',
#  'nikunj',
#  'number',
#  'office',
#  'old form',
#  'one',
#  'online facility',
#  'online website',
#  'only suggestion',
#  'option',
#  'other',
#  'other amc',
#  'other amcs',
#  'other amcs birla',
#  'other fund house',
#  'other ifas',
#  'outcall ifa',
#  'page',
#  'pager',
#  'part',
#  'payment mode',
#  'pdf',
#  'people',
#  'performance sheet',
#  'person',
#  'physical form',
#  'pie chart',
#  'place',
#  'post',
#  'poster',
#  'practical problem',
#  'presentation',
#  'print',
#  'problem',
#  'product infomration',
#  'product information',
#  'product knowledge',
#  'product launching',
#  'program',
#  'programe',
#  'programme',
#  'proper factsheet',
#  'proper fund update',
#  'proper service',
#  'proper time',
#  'proper timely basis',
#  'proper update',
#  'purpose',
#  'qualification',
#  'quarter',
#  'query',
#  'rajiv chunawala',
#  'reason',
#  'record',
#  'redemption process',
#  'redemtion',
#  'region',
#  'registered address',
#  'regualr basis',
#  'regualr basis training session',
#  'regular basis',
#  'regular engagement',
#  'regular interaction',
#  'regular interval',
#  'regular invitaton',
#  'regular physical factsheet',
#  'regular statement',
#  'regular touch',
#  'regular update',
#  'relaince',
#  'related training',
#  'reliance',
#  'request',
#  'requirement',
#  'requirmente',
#  'rm',
#  'ruaral area',
#  'rural area',
#  'sale',
#  'sale support',
#  'saturday',
#  'sbi',
#  'scheme',
#  'scheme detail',
#  'scheme infomration',
#  'scheme name',
#  'seminar',
#  'senior management',
#  'service',
#  'session',
#  'several time',
#  'shape',
#  'short group',
#  'side',
#  'sip',
#  'sip form',
#  'sip table',
#  'sir',
#  'small meeting',
#  'small tarining',
#  'smartphone',
#  'sms',
#  'soa',
#  'social medium app',
#  'someone',
#  'sort',
#  'staff',
#  'statement',
#  'such meeting',
#  'such programme',
#  'sufficient form',
#  'suggestion',
#  'support',
#  'target',
#  'tax saver',
#  'taxation calculation',
#  'technical knowledge',
#  'terme',
#  'thing',
#  'thrice',
#  'time',
#  'time table',
#  'timely initmation',
#  'topic',
#  'touch',
#  'trainer',
#  'trainging event',
#  'training',
#  'training class',
#  'training meeting',
#  'training program',
#  'training programe',
#  'training programme',
#  'training session',
#  'trainning',
#  'trainning session',
#  'transaction',
#  'transaction form',
#  'trianing programme',
#  'twitter',
#  'type',
#  'update',
#  'upper level',
#  'usage',
#  'uti',
#  'visit',
#  'voice programme',
#  'webinar',
#  'website',
#  'week',
#  'whatsapp',
#  'whole kim',
#  'work',
#  'workshop',
#  'writing',
#  'year',
#  'year nobody'}

# %%
all_noun_lemma_2 = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<NOUN>',lemma=True)
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 119.13it/s]

# %%
all_noun_lemma_2
# Out:
# {'-',
#  'account',
#  'acitivite',
#  'activity',
#  'address',
#  'advantage',
#  'advisor',
#  'alert',
#  'amc',
#  'amcs',
#  'anything',
#  'app',
#  'application',
#  'applicationn',
#  'area',
#  'assistence',
#  'aum',
#  'aurangabad',
#  'awarene',
#  'awareness',
#  'awerence',
#  'awereness',
#  'basis',
#  'belgaum',
#  'benefit',
#  'bikaner',
#  'birla',
#  'blackrock',
#  'branch',
#  'brokerage',
#  'bsl',
#  'bslamc',
#  'bsll',
#  'bslmf',
#  'business',
#  'bussiness',
#  'calculation',
#  'call',
#  'cam',
#  'certification',
#  'change',
#  'chart',
#  'cheque',
#  'chunawala',
#  'class',
#  'client',
#  'co',
#  'colour',
#  'communication',
#  'company',
#  'conatct',
#  'concall',
#  'condition',
#  'conference',
#  'conversation',
#  'copy',
#  'crash',
#  'customer',
#  'day',
#  'debt',
#  'dehradhun',
#  'detail',
#  'dhanbad',
#  'dinner',
#  'dispatch',
#  'distributor',
#  'dividend',
#  'dsp',
#  'dynamic',
#  'easyness',
#  'education',
#  'email',
#  'end',
#  'engagement',
#  'equity',
#  'event',
#  'everything',
#  'experience',
#  'explanation',
#  'face',
#  'facebook',
#  'facility',
#  'fact',
#  'facthsheet',
#  'factsheet',
#  'feedback',
#  'file',
#  'fingo',
#  'fitness',
#  'food',
#  'form',
#  'format',
#  'fund',
#  'geeta',
#  'ghaziabad',
#  'gold',
#  'group',
#  'guidance',
#  'gurunath',
#  'handbook',
#  'hardcopy',
#  'hdfc',
#  'head',
#  'home',
#  'house',
#  'icici',
#  'ifa',
#  'ifas',
#  'improvement',
#  'incentive',
#  'infomration',
#  'information',
#  'initiative',
#  'initmation',
#  'interacation',
#  'interaction',
#  'internet',
#  'interval',
#  'investment',
#  'investor',
#  'invitaion',
#  'invitation',
#  'invitaton',
#  'issue',
#  'jammu',
#  'jodhpur',
#  'khammam',
#  'kim',
#  'kind',
#  'knowledge',
#  'kolhapur',
#  'kyc',
#  'l',
#  'lack',
#  'launching',
#  'level',
#  'load',
#  'location',
#  'luanche',
#  'lucknow',
#  'mail',
#  'man',
#  'management',
#  'manager',
#  'mark',
#  'market',
#  'marketing',
#  'medium',
#  'meerut',
#  'meeting',
#  'mf',
#  'mistake',
#  'mode',
#  'model',
#  'month',
#  'monthlty',
#  'moradabad',
#  'motivation',
#  'mumbai',
#  'nach',
#  'nagar',
#  'name',
#  'neft',
#  'nfo',
#  'nikunj',
#  'nobody',
#  'number',
#  'office',
#  'one',
#  'operation',
#  'option',
#  'other',
#  'page',
#  'pager',
#  'part',
#  'partner',
#  'payment',
#  'pdf',
#  'people',
#  'performance',
#  'person',
#  'pie',
#  'place',
#  'plan',
#  'planning',
#  'portal',
#  'post',
#  'poster',
#  'presentation',
#  'presention',
#  'print',
#  'problem',
#  'process',
#  'product',
#  'program',
#  'programe',
#  'programme',
#  'purpose',
#  'qualification',
#  'quarter',
#  'query',
#  'rajiv',
#  'reason',
#  'record',
#  'redeemption',
#  'redemption',
#  'redemtion',
#  'regard',
#  'region',
#  'registration',
#  'relaince',
#  'reliance',
#  'relief',
#  'request',
#  'requirement',
#  'requirmente',
#  'return',
#  'rm',
#  'sale',
#  'saturday',
#  'saver',
#  'sbi',
#  'scenario',
#  'scheme',
#  'seminar',
#  'service',
#  'session',
#  'shape',
#  'sheet',
#  'side',
#  'sip',
#  'sir',
#  'smartphone',
#  'sms',
#  'soa',
#  'someone',
#  'sort',
#  'speaker',
#  'specialist',
#  'staff',
#  'statement',
#  'statment',
#  'suggestion',
#  'sunlife',
#  'support',
#  'table',
#  'target',
#  'tarining',
#  'tax',
#  'taxation',
#  'tea',
#  'terme',
#  'thing',
#  'thrice',
#  'time',
#  'topic',
#  'touch',
#  'trainer',
#  'trainging',
#  'training',
#  'trainning',
#  'traning',
#  'transaction',
#  'trb',
#  'trianing',
#  'twitter',
#  'type',
#  'update',
#  'usage',
#  'uti',
#  'visit',
#  'voice',
#  'webinar',
#  'website',
#  'week',
#  'whatsapp',
#  'work',
#  'workshop',
#  'writing',
#  'year',
#  'yield'}

# %%
dicts = {
    "activity":["acitivite"],
    "amc":["amcs"],
    "application":["applicationn","app","apps"],
    "awareness":["awarene","awareness","awerence",],
    "ifa":["ifas"],
    "information":["infomration"]
}

# %%
temp_dict = {}

for key, values in dicts.items():
    for value in values:
        temp_dict[value]=key

# %%
def _make_dict_cleaning(s, w_dict):
    s = w_dict.get(s, s)
    return s

# %%
t_data = data.L1_Verbatim.values

# %%
t_data = [' '.join([_make_dict_cleaning(i,temp_dict) for i in t.split()]) for t in t_data]

# %%
temp_dict
# Out:
# {'acitivite': 'activity',
#  'amcs': 'amc',
#  'applicationn': 'application',
#  'app': 'application',
#  'apps': 'application',
#  'awarene': 'awareness',
#  'awareness': 'awareness',
#  'awerence': 'awareness',
#  'ifas': 'ifa',
#  'infomration': 'information'}

# %%
t_data
# Out:
# ['and i am not getting the factsheets on time if you send me one factsheet twice in a month then it would be better .',
#  '( 4 ) training programme of birla is also good .',
#  'i am not receiving the fund updates on time nor i am getting the nfo forms if you arrange to send the forms then it would be better and also if you send the one pager of the good performing schemes it would be convenient for me to make understand regarding the same to my clients , where as other amc are providing the same .',
#  'and if you send me some sip and common application forms then its would be better .',
#  'if he visit twice in a week then it would be very convenient for me because it is not possible for me to visit frequently to krishna nagar to collect the forms',
#  'so i told him to speed post the forms and soa on my home address so that i can deliver the soa on time to the investors .',
#  'suggestion : the trainings programs should be arranged regularly , atleast once is a quarter .',
#  'the topics related to markets and others can be discussed .',
#  '( 1 ) as compared to other fund houses , birla is providing more trainings to ifa to provide the technical knowledge and also providing food to ifa .',
#  'whenever birla print the sip table , it should be simple as possible .',
#  'it should like a time table , so it wil be easy for a common man to understand .',
#  'suggestion : birla should provide more equity oriented trainings',
#  'e related to equity markets and equity schemes to ifa . trianing programme from reliance is good .',
#  'where i am are not receving the factsheet and forms .',
#  '> you people are inviting only few ifa to the meetings and training programmes , so why this is happening in dhanbad',
#  'not getting proper services such as fund performance information and forms on time .',
#  '( request taken for common application forms - amc - 1125159 - r0w7d7 )',
#  'in your common application form there should be option for payment mode ( redemtion and dividend ) like by cheque or neft , etc , so it should be there .',
#  '1 ) i am happy with the services of bslmf as rm is always available , forms are available , i am getting statement of account for my clients through hardcopy on time .',
#  'your motivation or awareness , encourage training is good and the same should be continued .',
#  '3 ) my suggestion is it would be more easier for us if you send the presentation , excel calculation by pdf or excel file through mail so that we can easily do the taxation calculation easily .',
#  'the service provided by the branch and rm ( gurunath ) is good and he takes the training classes well .',
#  '3 ) the only suggestion i would like to mention is , our rm ( gurunath ) takes nice training classes about the schemes especially how to invest in debt funds but it would be more easier for us if we have a handbook for this debt funds with exact explanation so that we dont want to go to search online all the time .',
#  '3 ) before 2 months a person from mumbai ( dharmendra ) came and gave a training on certified financial gold plan training and after that no one came and gave a training like that .',
#  'my suggestion is to arrange frequent training programs .',
#  'further , i would like to tell you that i am not getting invitations of your meetings , acitivites and sessions organised by you .',
#  'i come to know about the activities once they are completed whether it is organised in meerut or moradabad or dehradhun , etc .',
#  'i never get any factsheet or any forms from your side , i never get any information regarding the product information and which fund performance and any feedback .',
#  'like : i am not receive any forms and fact sheet .',
#  'now i am not receiving any application , forms this reason i have major business provide to other amc like : icici mf .',
#  '( request mark regard : form form and application )',
#  '1 ) there should be some information provided or training provided regarding the funds mainly the debt funds .',
#  '3 ) i am not getting sufficient forms from bslmf , i am downloading them , so it would be nice if you provide equity and tax saver / elss forms as a hardcopy .',
#  '( tagged in dynamics for forms )',
#  '2 ) it would be nice if you provide common application form 20 , sip application forms',
#  '20 and kyc10 forms as a hardcopy .',
#  '( tagged in dynamics for forms )',
#  '1 ) it would be nice if some training and meetings will be conducted by bslmf regarding some scheme and their advantages for ifa .',
#  'so , i have asked you people to send me application forms',
#  '( tagged in dynamics for forms ) = =',
#  'after that icici suggestion : interactions meetings should be conducted , whenever market crashes then meetings should be conducted as well as with investors also , so it would be better , you are informing during nfo meeting only .',
#  'the training which you give should be in short groups in bsl office which results in more productive and creative like training of 10 to 15 persons which results in giving more knowledge .',
#  'big event doesnt seems to be more meaningful compared to small meetings arranged at regular interval like quarterly it should be arranged .',
#  'no trainnings are arranged for us like what to fill up in the form only targets are given like this much of sales you have to do its not in bsl but for every amc',
#  'i myself learnt how to filll up the form , this small tarining you can arrange from branch , there is no thing like one to one',
#  ', big events are organised in that we are not receiving any benefit except one good tea and dinner sometimes ckyc form is getting changed or other so for that mf house should guide us , practical problems are there which should be solved from the branch itself by calling two or four persons',
#  'even my rm didnt called me till now , and when we fill up the forms they say that over - writing is not allowed , there are no trainings or any updates from your end and they are always finding mistakes in our work .',
#  'if fingo got launched so for that you should arrange the trainning even i dont know , rm is not aware ( further outcall ifa and asked to elaborate about lack of sales support on 01 .',
#  "they are not in regular touch and also does ' nt provide any form and applications upfrontly unless and until i call there for several times .",
#  'as other amc upfrontly sends all my requirmentes like form and applications while you people do not provide even after asking from your end .',
#  'there is no rm from your end , no communication , no scheme details , no factsheet etc .',
#  'so it would be nice if you could arrange someone to guide me on using the online websites .',
#  'i am regularly attaining your meeting and trainings and they are useful and knowledgeable and motivational speakers are coming which is very good .',
#  "i called at the bikaner branch for the forms but they are not sending it so how ' l we will do business with birla sunlife .",
#  'there are no feedbacks , no updates , no trainings conducted .',
#  'the last meeting which was organised in jodhpur their the trainer was not proper .',
#  'i am regularly attaining the meetings and they are useful',
#  'i am getting the forms on time .',
#  'i am not getting regular updates from rm , rm is not in regular touch with me , i am also not getting forms and factsheets , i am also aware of the meeting conducted by you in ghaziabad .',
#  '( request taken for factsheet ,',
#  'common application forms and transactions forms - amc - 1411178 - k4b7w1 )',
#  'suggestion : i am not receiving the factsheet every month , and whereas from other amc i am receiving it regularly',
#  'i am not aware of any new nfo details and even forms and application are',
#  'there was a meeting / training regarding the debt funds i liked the training session',
#  'first there were training programes held',
#  'but now it has not been held in our region .',
#  'there is no information on any new changes taking place , forms are not available , so if i go at branch then only i come to know .',
#  '( here taken request for forms and factsheet under - amc - 1137102 - k5q3z9 )',
#  '1 ) i have seen that application forms are changing very frequently , why dont you keep it uniform , so cams should launch common application forms for all the amc , so that would be solution for this',
#  'suggestion : it would be nice if bslmf will conduct some training programmes for ifa in jammu , because other amc are providing these trainings regularly for market related or how to handle customer , tackle customer , how to answer their queries like icici , relaince & hdfc is providing training every month even webinars are conducted by them .',
#  '1 ) as other amc are supporting more than bslmf , in other amc they are providing good services as regular interactions and conatcts with rm , they are conducting meeting regularly .',
#  'i usually tell all the companies that please give guidance or say trainning sessions to the distributors , with bsl i think is very less once in a year and conference call is also very less that i want more so that i can work more with bsl , hdfc and idfc people',
#  '( hence far marked ) 3 ) i am not getting regular invitaton for any programmes conducted by bslmf , i just got one invitaion , because earlier i did not received any invitation , so i find that may be i am not providing the business',
#  ', that is why i am not getting any invitations for such programmes .',
#  '4 ) it would be nice if you provide forms of all types , commmon application forms , transaction forms and other all forms like 20 - 25 number of forms .',
#  '( tagged in dynamics for forms )',
#  'if you arrange a training session quarterly regarding the current market scenario and fund updates which fund we should suggest to the investors then it would be very convenient for us .',
#  '1 ) it would be nice if you conduct more training programmes and good support from rm like regular engagement atleast once in a month and',
#  'proper updates should be provided by rm like marketing updates and factsheet .',
#  'suggestion : you should provide the hard copy ( factsheet ) on every montly basis .',
#  '3 ) you should provide hardcopy of factsheets on monthly basis , because there are 15 or 20 ifa who are strong so atleast to them',
#  'you should provide proper factsheets on time , it would be nice if you provide 1 factsheet on monthly basis .',
#  '( tagged in dynamics for factsheet ) =',
#  'distributor engagement programs are good',
#  'trainings are not conducted .',
#  'there are no services , no forms , no rm are available . due to this reason my aum is less with bsll .',
#  '( taken request for forms and factsheet - amc - 1218311 - c9w8d3 )',
#  'all staffs are providing very co - perative . suggestion : you should conduct more awareness training , product knowledge & market information .',
#  'earlier you had provided one training with certification .',
#  'this training is for to increase the qualification for gold specialist , to financial planning',
#  'it has 4 part where as only first part training has been taken but regarding the model',
#  'the birla did not take it initiative , so if the you further provide the training regarding the same then it would be very helpful',
#  'i am not getting common application forms and my clients are also not getting there account statements on time , from branch',
#  'so , if you send 10 common application forms with nach form , 1 factsheet on my home address then it would be very convenient .',
#  'shubha from branch of aurangabad providing me services , all staff is good 2 ) training meetings conducted by bslmf are verey good but from last 3 - 4 months dont know that any meetings have been conducted or not , or might be possible that i ahve not attended them 3 ) bslmf funds are good , bsl frontline equity fund , bsl tax relief 96 fund are good',
#  'suggestion : there should be some fitness workshop and any activities as the other amc',
#  'and it should be held in every saturdays of every month .',
#  'education training programmes conducted by bslmf are wonderful as nop other amc are providing these facilities .',
#  '2 ) it would be nice if some training programme will be conducted regarding any new changes and market conditions .',
#  '2 ) the services is provided to me so good like providing forms and factsheet and afrontly asking of any assistence , i am receiving daily sms alerts .',
#  'my record do we should be motivated , may be in shape of sort of incentive and let me tell you i have the minimum redeemption in my investment schemes of my clients reason being from day one',
#  'there was a conference regarding the mutual fund taken by the fund manager which was good .',
#  'there should be programmes held for us to gain some support from your end like arranging training for new luanches , product information , encourage training is good',
#  'i am not getting the new nfo updates and forms on time , where as uti is providing the same .',
#  'my rm is not contacting me nor providing any information , when ever there is any meeting he never inform me .',
#  'at kolhapur when ever there are meetings , we are not invited for that , where as other ifa are called , provided travelling facilities , etc who are not doing much business .',
#  'i have stopped attaining meetings now .',
#  'i even dont get the monthly factsheet and forms , so i call geeta and ask for the same .',
#  'i am not getting the factsheets , fatca forms , or any kind of information on time .',
#  'there was a training regarding debt funds i liked the training it was good .',
#  'i am not receiving fact sheet and performance sheet on proper timely basis .',
#  'you should provide the fact sheet and performance sheet on monthly basis .',
#  'over all experience is good , but i am not getting the factsheet monthly on time , if you provide me this m = month factsheet then it will be helpful .',
#  'from last one year i am not getting the forms .',
#  'i am happy with the services of bslmf as getting forms regularly , initmation and statements i am getting regularly .',
#  'and if you arrange training regarding the market updates then it would be very helpful .',
#  'if you send 2 factsheets monthly by post then it would be very convenient .',
#  'i have a good experience with bsl mf as my work and query are getting solved easily from my rm ( mr rajiv chunawala ) and even my rm recieves good co - operation from branch frequently changing format of forms should be stopped like common application form , kyc form etc',
#  'there should be some easyness dsp blackrock is using common application form which is very simple and very short , while bsl is using 3 pages for the common application form',
#  '1 ) i am not receiving hard copy fact sheet from your end on regular basis as i am receiving it from other amc like reliance .',
#  'bslamc should send 2 hard copy factsheet at my registered address on monthly basis .',
#  'suggestion : you should conduct more awareness training , product knowledge & market information .',
#  'allready icici mf conduct the this programes on proper timely basis .',
#  'and the fund related training is good and compare to other amc birla',
#  'is sharing interesting topic in the meeting .',
#  'the other amc also conducting very good meeting regarding the product launching , fund information .',
#  'suggestion : i have noticed one thing in factsheet , that in debt funds you have given pie chart in factsheet , so i request to change the colours',
#  'but we dont know anything about it much , so you should conduct meeting for motivating purpose and should give the schemes information in detail i am at khammam location .',
#  'from last 1 year nobody is in touch with me , not visiting , not providing any factsheet , not any call and not even any funds information i am receiving from bslmf but other amc are providing good services and in regular touch and regualr basis visit my office , in my last 21 years , i have not seen this type of worst manager like mr .',
#  '> i have to call thrice for factsheet , and',
#  'then after 3 months we get the factsheet , so we feel like we are begging for factsheet .',
#  '( tagged in dynamics for factsheet )',
#  'the rm is not in regular touch with me and he is not intimating me about the training or meeting .',
#  'if you provide me 3 factsheets monthly on my home address then it would very convenient .',
#  'i am getting good services from my rm , he is providing me the forms and all timely .',
#  ', i am not receiving any form and application upfrontly , when i am visiting then',
#  'bslmf provides form and application .',
#  '1 ) i am happy with the services of bslmf as my clients getting regular statement , redemptions process and seminars taken are good .',
#  'i am getting the forms on time .',
#  '( 2 ) training programmes are very good , voice programmes are fantastic .',
#  'i am receiving the sms and email regarding the market updates and and i am not getting the factsheets if you provide the factsheets on monthly basis',
#  'so if i have get fund performance return chart of all the funds of bsl mf , i am getting regular physical factsheet from your dhanbad branch',
#  'i am not receiving any forms or factsheet anything from your end on proper time .',
#  '( marked a request for factsheet on his registered address . )',
#  'the training regarding bussiness improvement , knowledge improvement which i am receiving from your end should be continued on monthly basis even you have launched active account application',
#  '2 ) i am happy with the services of bslmf , as i am happy with the staff of lucknow branch office and training programes',
#  'are conducted by bslmf .',
#  'once i had faced a problem that 2 months back i had submitted a application of my customer sip registrations , and in that application i forgot to mention the name of the fund in sip form , whereas in common application form',
#  'i accept that it was my mistake that i did not mentioned scheme name but cant the staff can mention in it as it was already mentioned in common application form .',
#  'i am not getting factsheets from your end , due to this',
#  '( here request taken for facthsheet under amc - 1136816 - n4q8r0 )',
#  'and i get the stationary like the factsheets ,',
#  'kim and forms are available when i had the requirement .',
#  'bsl mf conducted the investor education programes and awereness presention which are very nice .',
#  'but the other amc provide us this knowledge through direct face to face conversation , presentations , social media application like facebook , twitter and whatsapp .',
#  'there should be training organised for ifa to teach the online facilities .',
#  'the taining program with nikunj is good .',
#  'i am getting good services from bslmf , but it would be nice if bslmf will arrange some trainging events for ifa , as icici is conducting good training events for ifa regularly .',
#  'icici is sending timely initmations for everything like forms has been changed in cams',
#  'they send me that initmation and new forms also , but from bslmf end there are not updated regarding this , and there by rejecting my applications that its old form .',
#  'that bsl mf are conducting awareness programes , encourage training sessions and that should be continued .',
#  'recently i am not receive any forms and fact sheet and any nfo from upfrontly .',
#  'when calling to branch for factsheets and forms after you will provide .',
#  'you should upfrontly provide the form and fact sheet on proper timely basis .',
#  '( take request for form and fast sheet )',
#  'i am not receiving the forms and factsheet on time and also if you provide the fund updates regularly then it would be very helpful .',
#  'but still not received any forms , so please inform them to provide dispatch details or send forms immediately .',
#  '( tagged in dynamics for forms amc - 1469340 - f5h5y8 )',
#  'like : branch rm visit , interacation and communications are very low not in regular touch also training sessions and funds information',
#  'you should meet new ifa regularly as compared to hdfc mf .',
#  'is not coming to me , physical forms not getting from last 6 - 7 months',
#  'your belgaum branch services is not proper because any application , forms and account statment request and brokerage statment received after i give 2 - 3 times follow up .',
#  'gst regarding hdfc and all bslmf has not conducted any trainings .',
#  'the scheme which are promoted like bsl frontline equity fund , bsl dividend yield , bsl equity fund , bsl equity advantage fund have benefitted the investor more and more details are available on monthlty factsheet and even i am receiving sms from bsl regarding current economic scenario and',
#  'which schemes to promote you should promote that now a days ifa can initiate a transaction / investment through internet and smartphone so for that we should get the training regarding the usage of this application ( inform ifa about fingo partner application and advisor portal )',
#  'you should be provide the fact sheet and kim on monthly basis through hard copy .',
#  '( taken request for fact sheet and form )',
#  'mostly i am dealing with ruaral area for business where i am not getting any factsheet and visit of rm',
#  'as uti is coming and giving training for the same and hence i am giving more business to uti .',
#  'even on regualr basis training session etc . should be there .',
#  'but this month i am not able to attend that .',
#  'bsl mf conducted the investor education programes and awereness presention which are very nice .',
#  'bsl mf partner programes ( awareness traning program ) is very nice .',
#  'there is no training regarding the debt and equity schemes , also not getting proper fund updates then if we want to share our problems to the upper level we are not able to do not that , where as uti , icici , kotak , sbi are providing the services .',
#  'so if you arrange the training regarding the same then it would be very convenient for us .',
#  'i am getting sometimes mails from your head - office and somewhat information from factsheet',
#  'i am getting invitations',
#  'whenever any events are organised , i have no issues on this side .',
#  'in that like meeting senior management like bala sir ,',
#  'my rm meets me only in the meetings and events and their he comes and meets me which is wrong , they should meet us apart from such meeting and events also .',
#  '( taken request for hard copy of common application forms and factsheet - amc - 1219438 - n1y2j0 ) ( this feedback was taken on 03 .',
#  'bsl mf should conduct more awarenes programes in rural area in termes of taking training for mutual fund .',
#  'also bsl trb programes are very well .',
#  'suggestion : i am associated to many other amc , but with bsl there is a lack of training and workshops .',
#  'your concalls are regular , but there are no trainings sessions .',
#  '3 ) i require you to send the hard copies of common application forms and factsheets atleast once in every 3 months .',
#  'if you provide me one current factsheet then it would be very fruitful .',
#  '( further tagged for factsheet )',
#  'i had given only application at your branch as forms were not available to me and if i download it from your website then i have to down load whole kim and then take print out',
#  'i would like to have some posters from your end and factsheet and forms also .']

# %%
all_noun_lemma_1 = get_all_noun_chunks(t_data,pattern = r'<NOUN>',lemma=True)
print(len(all_noun_lemma_2))
all_noun_lemma_2 = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<NOUN>',lemma=True)
print(len(all_noun_lemma_2))
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 126.23it/s]
#   6%|▋         | 13/200 [00:00<00:01, 124.44it/s]
# 281
# 100%|██████████| 200/200 [00:01<00:00, 125.23it/s]
# 281

# %%
all_noun_lemma_2.difference(all_noun_lemma_1)
# Out:
# {'amcs', 'app', 'applicationn', 'awerence', 'ifas', 'infomration'}

# %%
all_noun_lemma_2
# Out:
# {'-',
#  'account',
#  'acitivite',
#  'activity',
#  'address',
#  'advantage',
#  'advisor',
#  'alert',
#  'amc',
#  'anything',
#  'application',
#  'area',
#  'assistence',
#  'aum',
#  'aurangabad',
#  'awarene',
#  'awareness',
#  'awereness',
#  'basis',
#  'belgaum',
#  'benefit',
#  'bikaner',
#  'birla',
#  'blackrock',
#  'branch',
#  'brokerage',
#  'bsl',
#  'bslamc',
#  'bsll',
#  'bslmf',
#  'business',
#  'bussiness',
#  'calculation',
#  'call',
#  'cam',
#  'certification',
#  'change',
#  'chart',
#  'cheque',
#  'chunawala',
#  'class',
#  'client',
#  'co',
#  'colour',
#  'communication',
#  'company',
#  'conatct',
#  'concall',
#  'condition',
#  'conference',
#  'conversation',
#  'copy',
#  'crash',
#  'customer',
#  'day',
#  'debt',
#  'dehradhun',
#  'detail',
#  'dhanbad',
#  'dinner',
#  'dispatch',
#  'distributor',
#  'dividend',
#  'dsp',
#  'dynamic',
#  'easyness',
#  'education',
#  'email',
#  'end',
#  'engagement',
#  'equity',
#  'event',
#  'everything',
#  'experience',
#  'explanation',
#  'face',
#  'facebook',
#  'facility',
#  'fact',
#  'facthsheet',
#  'factsheet',
#  'feedback',
#  'file',
#  'fingo',
#  'fitness',
#  'food',
#  'form',
#  'format',
#  'fund',
#  'geeta',
#  'ghaziabad',
#  'gold',
#  'group',
#  'guidance',
#  'gurunath',
#  'handbook',
#  'hardcopy',
#  'hdfc',
#  'head',
#  'home',
#  'house',
#  'icici',
#  'ifa',
#  'improvement',
#  'incentive',
#  'information',
#  'initiative',
#  'initmation',
#  'interacation',
#  'interaction',
#  'internet',
#  'interval',
#  'investment',
#  'investor',
#  'invitaion',
#  'invitation',
#  'invitaton',
#  'issue',
#  'jammu',
#  'jodhpur',
#  'khammam',
#  'kim',
#  'kind',
#  'knowledge',
#  'kolhapur',
#  'kyc',
#  'l',
#  'lack',
#  'launching',
#  'level',
#  'load',
#  'location',
#  'luanche',
#  'lucknow',
#  'mail',
#  'man',
#  'management',
#  'manager',
#  'mark',
#  'market',
#  'marketing',
#  'medium',
#  'meerut',
#  'meeting',
#  'mf',
#  'mistake',
#  'mode',
#  'model',
#  'month',
#  'monthlty',
#  'moradabad',
#  'motivation',
#  'mumbai',
#  'nach',
#  'nagar',
#  'name',
#  'neft',
#  'nfo',
#  'nikunj',
#  'nobody',
#  'number',
#  'office',
#  'one',
#  'operation',
#  'option',
#  'other',
#  'page',
#  'pager',
#  'part',
#  'partner',
#  'payment',
#  'pdf',
#  'people',
#  'performance',
#  'person',
#  'pie',
#  'place',
#  'plan',
#  'planning',
#  'portal',
#  'post',
#  'poster',
#  'presentation',
#  'presention',
#  'print',
#  'problem',
#  'process',
#  'product',
#  'program',
#  'programe',
#  'programme',
#  'purpose',
#  'qualification',
#  'quarter',
#  'query',
#  'rajiv',
#  'reason',
#  'record',
#  'redeemption',
#  'redemption',
#  'redemtion',
#  'regard',
#  'region',
#  'registration',
#  'relaince',
#  'reliance',
#  'relief',
#  'request',
#  'requirement',
#  'requirmente',
#  'return',
#  'rm',
#  'sale',
#  'saturday',
#  'saver',
#  'sbi',
#  'scenario',
#  'scheme',
#  'seminar',
#  'service',
#  'session',
#  'shape',
#  'sheet',
#  'side',
#  'sip',
#  'sir',
#  'smartphone',
#  'sms',
#  'soa',
#  'someone',
#  'sort',
#  'speaker',
#  'specialist',
#  'staff',
#  'statement',
#  'statment',
#  'suggestion',
#  'sunlife',
#  'support',
#  'table',
#  'target',
#  'tarining',
#  'tax',
#  'taxation',
#  'tea',
#  'terme',
#  'thing',
#  'thrice',
#  'time',
#  'topic',
#  'touch',
#  'trainer',
#  'trainging',
#  'training',
#  'trainning',
#  'traning',
#  'transaction',
#  'trb',
#  'trianing',
#  'twitter',
#  'type',
#  'update',
#  'usage',
#  'uti',
#  'visit',
#  'voice',
#  'webinar',
#  'website',
#  'week',
#  'whatsapp',
#  'work',
#  'workshop',
#  'writing',
#  'year',
#  'yield'}
