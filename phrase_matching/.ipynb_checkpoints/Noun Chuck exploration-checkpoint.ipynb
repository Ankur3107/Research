# %%
import pandas as pd
import spacy
from spacy.matcher import Matcher
from spacy import displacy
import warnings
warnings.filterwarnings('ignore')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
data = pd.read_excel('l1_12_sentiment_modified.xlsx',sheet_name="FundPerformance")

# %%
data.head()
# Out:
#    Unnamed: 0                                           Verbatim  \
# 0           0  i do recommend bsl frontline fund , bsl midcap...
# 1           1  1 ) as an ifa the experience is very good . mo...
# 2           2  ( 1 ) both equity and debt schemes of birla ar...
# 3           3  1 ) i am very happy with the services of bslmf...
# 4           4  1 ) i am happy with the fund performance of bs...
#
#                                          L1_Verbatim                      L2  \
# 0  i do recommend bsl frontline fund , bsl midcap...         Rate of returns
# 1  most of the funds like bsl frontline equity fu...  Consistency of returns
# 2  ( 1 ) both equity and debt schemes of birla ar...  Consistency of returns
# 3  but when i compare it with other amc for fund ...    Unspecified / Others
# 4  1 ) i am happy with the fund performance of bs...    Unspecified / Others
#
#             Sentiment
# 0            Positive
# 1            Positive
# 2            Positive
# ...

# %%
def get_all_matched_pharses(text, pattern):
    print(text)
    matcher = Matcher(nlp.vocab)

    matcher.add('IPHONE_PATTERN', None, pattern)

    doc = nlp(text)
    #print(list(doc.noun_chunks))
    print(' '.join(['<%s>' % w.tag_ for w in doc]))

    matches = matcher(doc)
    
    for match_id, start, end in matches: 
        span = doc[start:end]
        print(span.text)

# %%
pattern = [
    {'TAG':'JJ','OP':'*'},
    #{'TAG':{'REGEX' : '(NN|NNS|NNP)'},'OP':'+'}
    {'TAG': {'IN': ['NN', 'NNS', 'NNP']}}
]
#text = "2018 FIFA World Cup: France won!"

get_all_matched_pharses(data.L1_Verbatim.values[9],pattern)
# Out:
# and i do recommend bsl frontline equity fund , bsl equity fund ,
# <CC> <PRP> <VBP> <VB> <JJ> <JJ> <NN> <NN> <,> <NN> <NN> <NN> <,>
# bsl frontline equity
# frontline equity
# equity
# fund
# bsl
# equity
# fund

# %%
pattern = [
    {'TAG':'JJ','OP':'+'},
    {'TAG':{'REGEX' : '(NN|NNS|NNP)'},'OP':'+'}
    #{'TAG': {'IN': ['NN', 'NNS', 'NNP']},'OP':'+'}
]
#text = "2018 FIFA World Cup: France won!"

get_all_matched_pharses(data.L1_Verbatim.values[9],pattern)
# Out:
# and i do recommend bsl frontline equity fund , bsl equity fund ,
# <CC> <PRP> <VBP> <VB> <JJ> <JJ> <NN> <NN> <,> <NN> <NN> <NN> <,>
# frontline equity
# bsl frontline equity
# frontline equity fund
# bsl frontline equity fund

# %%
adj_doc = nlp("The company's customer service was terrible.")
verb_doc = nlp("They kept increasing my phone bill")

def get_compound_pairs(doc, verbose=False):
    """Return tuples of (multi-noun word, adjective or verb) for document."""
    compounds = [tok for tok in doc if tok.dep_ == 'compound'] # Get list of compounds in doc
    compounds = [c for c in compounds if c.i == 0 or doc[c.i - 1].dep_ != 'compound'] # Remove middle parts of compound nouns, but avoid index errors
    tuple_list = []
    if compounds: 
        for tok in compounds:
            pair_item_1, pair_item_2 = (False, False) # initialize false variables
            noun = doc[tok.i: tok.head.i + 1]
            pair_item_1 = noun
            # If noun is in the subject, we may be looking for adjective in predicate
            # In simple cases, this would mean that the noun shares a head with the adjective
            if noun.root.dep_ == 'nsubj':
                adj_list = [r for r in noun.root.head.rights if r.pos_ == 'ADJ']
                if adj_list:
                    pair_item_2 = adj_list[0] 
                if verbose == True: # For trying different dependency tree parsing rules
                    print("Noun: ", noun)
                    print("Noun root: ", noun.root)
                    print("Noun root head: ", noun.root.head)
                    print("Noun root head rights: ", [r for r in noun.root.head.rights if r.pos_ == 'ADJ'])
            if noun.root.dep_ == 'dobj':
                verb_ancestor_list = [a for a in noun.root.ancestors if a.pos_ == 'VERB']
                if verb_ancestor_list:
                    pair_item_2 = verb_ancestor_list[0]
                if verbose == True: # For trying different dependency tree parsing rules
                    print("Noun: ", noun)
                    print("Noun root: ", noun.root)
                    print("Noun root head: ", noun.root.head)
                    print("Noun root head verb ancestors: ", [a for a in noun.root.ancestors if a.pos_ == 'VERB'])
            if pair_item_1 and pair_item_2:
                tuple_list.append((pair_item_1, pair_item_2))
    return tuple_list

# %%
print(data.L1_Verbatim.values[0])
print(list(nlp(data.L1_Verbatim.values[0]).noun_chunks))
get_compound_pairs(nlp(data.L1_Verbatim.values[0]))
# Out:
# i do recommend bsl frontline fund , bsl midcap fund , bsl dynamic bond fund , bsl balanced 95 fund which are providing good returns .
# [i, bsl frontline fund, bsl midcap fund, bsl dynamic bond fund, bsl, 95 fund, good returns]
# [(frontline fund, recommend)]

# %%
#doc = nlp(u'Mark and John are sincere employees at Google.')
doc = nlp('i am not receiving the factsheet every month , and whereas from other amcs i am receiving it regularly')
noun_adj_pairs = []
for i,token in enumerate(doc):
    if token.pos_ not in ('NOUN','PROPN'):
        continue
    for j in range(i+1,len(doc)):
        if doc[j].pos_ == 'ADJ':
            noun_adj_pairs.append((token,doc[j]))
            break
noun_adj_pairs
# Out:
# [(factsheet, other), (month, other)]

# %%
# link = https://stackoverflow.com/questions/55393087/pos-pattern-mining-with-spacy

import re
# Patters we are intrested in 
patterns = ["NOUN +"]

# Convert each pattern into regular expression
re_patterns = [" ".join(["(\w+)_!"+pos for pos in p.split()]) for p in patterns]


def extract(nlp, text, patterns, re_patterns):
    """Extracts the pieces in text maching the POS pattern in patterns

    args:
        nlp : Loaded Spicy model object
        text: The input text
        patterns: The list of patters to be searched
        re_patterns: The patterns converted into regex

    returns: A list of tuples of form (t,p) where 
    t is the part of text matching the pattern p in patterns
    """
    doc = nlp(text)   
    matches = list()
    text_pos = " ".join([token.text+"_!"+token.pos_ for token in doc])
    
    for i, pattern in enumerate(re_patterns):
        for result in re.findall(pattern, text_pos):
            matches.append([" ".join(result), patterns[i]])
    return matches

# Test it 
print (extract(nlp, data.L1_Verbatim.values[0], patterns, re_patterns))
# Out:
# [['bsl midcap', 'NOUN +'], ['bond fund', 'NOUN +'], ['fund which', 'NOUN +']]

# %%
#link:https://stackoverflow.com/questions/39100652/python-chunking-others-than-noun-phrases-e-g-prepositional-using-spacy-etc

def get_pps(doc):
    "Function to get PPs from a parsed document."
    pps = []
    for token in doc:
        # Try this with other parts of speech for different subtrees.
        if token.pos_ == 'ADP':
            pp = ' '.join([tok.orth_ for tok in token.subtree])
            pps.append(pp)
    return pps

ex = data.L1_Verbatim.values[1]
doc = nlp(ex)

print(get_pps(doc))
# Out:
# ['of the funds like bsl frontline equity fund , bsl equity fund , bsl 95 fund , bsl tax releif 96 fund interms of growth', 'like bsl frontline equity fund , bsl equity fund , bsl 95 fund , bsl tax releif 96 fund interms of growth', 'of growth']

# %%
from IPython.display import HTML
HTML('''<script>
code_show_err=false; 
function code_toggle_err() {
 if (code_show_err){
 $('div.output_stderr').hide();
 } else {
 $('div.output_stderr').show();
 }
 code_show_err = !code_show_err
} 
$( document ).ready(code_toggle_err);
</script>
To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.''')
# Out:
# <script>
# code_show_err=false;
# function code_toggle_err() {
#  if (code_show_err){
#  $('div.output_stderr').hide();
#  } else {
#  $('div.output_stderr').show();
#  }
#  code_show_err = !code_show_err
# }
# $( document ).ready(code_toggle_err);
# </script>
# To toggle on/off output_stderr, click <a href="javascript:code_toggle_err()">here</a>.

# %%
#link https://stackoverflow.com/questions/49954494/chunking-in-spacy

import textacy

sentence = data.L1_Verbatim.values[3]
#print(sentence)
pattern = r'<ADJ>*<NOUN>+'
doc = nlp(sentence)
lists = textacy.extract.pos_regex_matches(doc, pattern)
for list in lists:
    print(' '.join(['%s' % w.lemma_ for w in list.as_doc()]))
# Out:
# other amc
# fund performance
# other
# /Users/ankur.kumar/CustumApps/anaconda3/envs/tf_env/lib/python3.7/site-packages/textacy/extract.py:327: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   action="once",

# %%
def get_all_noun_chunks(texts, pattern, lemma=False):
    all_results = set()
    for text in texts:
        if type(text)==str:
            doc = nlp(text)
            lists = textacy.extract.pos_regex_matches(doc, pattern)
            for list in lists:
                if lemma:
                    all_results.add(' '.join(['%s' % w.lemma_ for w in list.as_doc()]))
                else:
                    all_results.add(list.text)
    return all_results

# %%
all_adj_noun = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<ADJ>*<NOUN>+')
all_noun = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<NOUN>+')
all_adj_noun_lemma = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<ADJ>*<NOUN>+',lemma=True)
all_noun_lemma = get_all_noun_chunks(data.L1_Verbatim.values,pattern = r'<NOUN>+',lemma=True)
# Out:
# /Users/ankur.kumar/CustumApps/anaconda3/envs/tf_env/lib/python3.7/site-packages/textacy/extract.py:327: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   action="once",
# /Users/ankur.kumar/CustumApps/anaconda3/envs/tf_env/lib/python3.7/site-packages/textacy/extract.py:327: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   action="once",
# /Users/ankur.kumar/CustumApps/anaconda3/envs/tf_env/lib/python3.7/site-packages/textacy/extract.py:327: DeprecationWarning: `pos_regex_matches()` has been deprecated! for similar but more powerful and performant functionality, use `textacy.extract.matches()` instead.
#   action="once",
# ...

# %%
len(all_adj_noun),len(all_noun),len(all_adj_noun_lemma),len(all_noun_lemma)
# Out:
# (884, 684, 812, 616)

# %%
# Out:
# 684

# %%
all_noun_lemma
# Out:
# {'%',
#  '% approx',
#  '% fund',
#  '% return',
#  '-',
#  '- cap',
#  '.',
#  '6nd',
#  'account',
#  'advanatge fund',
#  'advance fund',
#  'advantage fund',
#  'age',
#  'agi',
#  'akilesh',
#  'alot',
#  'amc',
#  'amc fund bsl',
#  'amc scheme',
#  'amc scheme interm',
#  'amc scheme performane response',
#  'amc servcie',
#  'amcs',
#  'amount',
#  'appreciation growth',
#  'arbitrage equity fund',
#  'arbitrage fund',
#  'area',
#  'arn',
#  'aspect',
#  'attachment',
#  'aum',
#  'aurangabad',
#  'axis',
#  'balance',
#  'balance advantage fund',
#  'balance category',
#  'balance category bsl balance',
#  'balance category sector bsl',
#  'balance fund',
#  'banking',
#  'baroda branch',
#  'basis',
#  'becaaue fund',
#  'because',
#  'behalf',
#  'behaviour',
#  'belgaum branch',
#  'birla',
#  'birla mf',
#  'birla mf fund return',
#  'birla sun',
#  'birla sun life',
#  'birla sun life advantage fund',
#  'birla sun life banking',
#  'birla sun life cash manager',
# ...

# %%
# ?textacy.extract.matches

# %%
doc = nlp(u"Give it back! He pleaded.")
span = doc[1:4]

# %%
d = span.as_doc()

# %%
' '.join(['%s' % w.lemma_ for w in span.as_doc()])
# Out:
# '-PRON- back !'
