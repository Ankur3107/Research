# %%
import pandas as pd
import json

# %%
data_file = '/Users/ankur.kumar/Downloads/albert_backup/SQuAD/dev-v2.0.json'

# %%
with open(data_file) as f:
    dataset_json = json.load(f)
    dataset = dataset_json['data']

# %%
dataset[0]
# Out:
# {'title': 'Normans',
#  'paragraphs': [{'qas': [{'question': 'In what country is Normandy located?',
#      'id': '56ddde6b9a695914005b9628',
#      'answers': [{'text': 'France', 'answer_start': 159},
#       {'text': 'France', 'answer_start': 159},
#       {'text': 'France', 'answer_start': 159},
#       {'text': 'France', 'answer_start': 159}],
#      'is_impossible': False},
#     {'question': 'When were the Normans in Normandy?',
#      'id': '56ddde6b9a695914005b9629',
#      'answers': [{'text': '10th and 11th centuries', 'answer_start': 94},
#       {'text': 'in the 10th and 11th centuries', 'answer_start': 87},
#       {'text': '10th and 11th centuries', 'answer_start': 94},
#       {'text': '10th and 11th centuries', 'answer_start': 94}],
#      'is_impossible': False},
#     {'question': 'From which countries did the Norse originate?',
#      'id': '56ddde6b9a695914005b962a',
#      'answers': [{'text': 'Denmark, Iceland and Norway', 'answer_start': 256},
# ...

# %%
def get_answer(ls):
    result = []
    for l in ls:
        result.append(l['text']) 
    return result

dataset_dict = {}
question_dict = {}

for ds in dataset:
    for ds_para in ds['paragraphs']:
        for ds_para_qas in ds_para['qas']:
            dataset_dict[ds_para_qas['id']] = get_answer(ds_para_qas['answers'])
            question_dict[ds_para_qas['id']] = ds_para_qas['question']

# %%
dataset_dict
# Out:
# {'56ddde6b9a695914005b9628': ['France', 'France', 'France', 'France'],
#  '56ddde6b9a695914005b9629': ['10th and 11th centuries',
#   'in the 10th and 11th centuries',
#   '10th and 11th centuries',
#   '10th and 11th centuries'],
#  '56ddde6b9a695914005b962a': ['Denmark, Iceland and Norway',
#   'Denmark, Iceland and Norway',
#   'Denmark, Iceland and Norway',
#   'Denmark, Iceland and Norway'],
#  '56ddde6b9a695914005b962b': ['Rollo', 'Rollo', 'Rollo', 'Rollo'],
#  '56ddde6b9a695914005b962c': ['10th century',
#   'the first half of the 10th century',
#   '10th',
#   '10th'],
#  '5ad39d53604f3c001a3fe8d1': [],
#  '5ad39d53604f3c001a3fe8d2': [],
#  '5ad39d53604f3c001a3fe8d3': [],
#  '5ad39d53604f3c001a3fe8d4': [],
#  '56dddf4066d3e219004dad5f': ['William the Conqueror',
#   'William the Conqueror',
#   'William the Conqueror'],
#  '56dddf4066d3e219004dad60': ['Richard I', 'Richard I', 'Richard I'],
#  '56dddf4066d3e219004dad61': ['Catholic', 'Catholic orthodoxy', 'Catholic'],
# ...

# %%
pred_file_single = '/Users/ankur.kumar/Desktop/predictions_single.json'
pred_file_ensemble = '/Users/ankur.kumar/Desktop/predictions_ensemble.json'

# %%
with open(pred_file_single) as f:
    preds_single = json.load(f)
    
with open(pred_file_ensemble) as f:
    preds_ensemble = json.load(f)

# %%
preds_single
# Out:
# {'56ddde6b9a695914005b9628': 'France',
#  '56ddde6b9a695914005b9629': '10th and 11th centuries',
#  '56ddde6b9a695914005b962a': 'Denmark, Iceland and Norway',
#  '56ddde6b9a695914005b962b': 'Rollo',
#  '56ddde6b9a695914005b962c': '10th',
#  '5ad39d53604f3c001a3fe8d1': '',
#  '5ad39d53604f3c001a3fe8d2': '',
#  '5ad39d53604f3c001a3fe8d3': '',
#  '5ad39d53604f3c001a3fe8d4': '',
#  '56dddf4066d3e219004dad5f': 'William the Conqueror',
#  '56dddf4066d3e219004dad60': 'Richard I of Normandy',
#  '56dddf4066d3e219004dad61': 'Christian',
#  '5ad3a266604f3c001a3fea27': '',
#  '5ad3a266604f3c001a3fea28': '',
#  '5ad3a266604f3c001a3fea29': '',
#  '5ad3a266604f3c001a3fea2a': '',
#  '5ad3a266604f3c001a3fea2b': '',
#  '56dde0379a695914005b9636': '',
#  '56dde0379a695914005b9637': '9th century',
#  '5ad3ab70604f3c001a3feb89': '',
#  '5ad3ab70604f3c001a3feb8a': '',
#  '56dde0ba66d3e219004dad75': '911',
#  '56dde0ba66d3e219004dad76': 'King Charles III',
#  '56dde0ba66d3e219004dad77': 'river Epte',
# ...

# %% [markdown]
# ## Predictions EDA

# %% [markdown]
# ### 1. How many No Answer?

# %%
count = 0
for key,value in dataset_dict.items():
    if len(value)==0:
        count+=1
        
print('Total No Answer (Actual):', count)
# Out:
# Total No Answer (Actual): 5945

# %%
count_single = 0
for key,value in preds_single.items():
    if value=='':
        count_single+=1
        
print('Total No Answer (Single Model Prediction) :', count_single)
# Out:
# Total No Answer (Single Model Prediction) : 6101

# %%
count_ensemble = 0
for key,value in preds_ensemble.items():
    if value=='':
        count_ensemble+=1
        
print('Total No Answer (Single Model Prediction) :', count_ensemble)
# Out:
# Total No Answer (Single Model Prediction) : 5888

# %%
print('Diff in Single Model Prediction and Actual :',count-count_single)
print('Diff in Ensemble Model Prediction and Actual :',count-count_ensemble)
# Out:
# Diff in Single Model Prediction and Actual : -156
# Diff in Ensemble Model Prediction and Actual : 57

# %% [markdown]
# ### 2. How many Answer mismatch?

# %%
import evaluation

# %%
exact_count_single = 0
for id, gold_answers in dataset_dict.items():
    a_pred = preds_single[id]
    
    if len(gold_answers) == 0 and a_pred=='':
        exact_count_single+=1
        continue
    elif len(gold_answers) == 0 and a_pred!='':
        continue
    exact_count_single+=max(evaluation.compute_exact(a, a_pred) for a in gold_answers)
    
print('Total mismatch using Single Model Prediction :', len(dataset_dict)-exact_count_single,' & Match Percentage :',exact_count_single/len(dataset_dict))
# Out:
# Total mismatch using Single Model Prediction : 1443  & Match Percentage : 0.8784637412616861

# %%
exact_count_ensemble = 0
for id, gold_answers in dataset_dict.items():
    a_pred = preds_ensemble[id]
    
    if len(gold_answers) == 0 and a_pred=='':
        exact_count_ensemble+=1
        continue
    elif len(gold_answers) == 0 and a_pred!='':
        continue
    exact_count_ensemble+=max(evaluation.compute_exact(a, a_pred) for a in gold_answers)
    
print('Total mismatch using Single Model Prediction :', len(dataset_dict)-exact_count_ensemble,' & Match Percentage :',exact_count_ensemble/len(dataset_dict))
# Out:
# Total mismatch using Single Model Prediction : 1407  & Match Percentage : 0.8814958308767793

# %% [markdown]
# ### No Answer Match

# %%
exact_no_answer_count_single = 0
wrong_no_answer_count_single = 0
for id, gold_answers in dataset_dict.items():
    a_pred = preds_single[id]
    
    if len(gold_answers) == 0 and a_pred=='':
        exact_no_answer_count_single+=1
        continue
    elif len(gold_answers) == 0 and a_pred!='':
        wrong_no_answer_count_single+=1
        continue

print('Total Match & Mismatch No Answer using Single Model Prediction :', exact_no_answer_count_single,wrong_no_answer_count_single)
# Out:
# Total Match & Mismatch No Answer using Single Model Prediction : 5553 392

# %%
exact_no_answer_count_ensemble = 0
wrong_no_answer_count_ensemble = 0
for id, gold_answers in dataset_dict.items():
    a_pred = preds_ensemble[id]
    
    if len(gold_answers) == 0 and a_pred=='':
        exact_no_answer_count_ensemble+=1
        continue
    elif len(gold_answers) == 0 and a_pred!='':
        wrong_no_answer_count_ensemble+=1
        continue

print('Total Match & Mismatch No Answer using Ensemble Model Prediction :', exact_no_answer_count_ensemble,wrong_no_answer_count_ensemble)
# Out:
# Total Match & Mismatch No Answer using Ensemble Model Prediction : 5476 469

# %% [markdown]
# ## Mis-Match Depth Analysis

# %%
mismatch_single_dict = {}
for id, gold_answers in dataset_dict.items():
    a_pred = preds_single[id]
    
    if len(gold_answers) == 0 and a_pred=='':
        exact_count_single+=1
        continue
    elif len(gold_answers) == 0 and a_pred!='':
        mismatch_single_dict[id] = a_pred
        continue
    elif max(evaluation.compute_exact(a, a_pred) for a in gold_answers) != 1:
        mismatch_single_dict[id] = a_pred

# %%
len(mismatch_single_dict)
# Out:
# 1443

# %%
mismatch_single_dict
# Out:
# {'56dddf4066d3e219004dad60': 'Richard I of Normandy',
#  '56dddf4066d3e219004dad61': 'Christian',
#  '56dde0379a695914005b9636': '',
#  '56dde0ba66d3e219004dad77': 'river Epte',
#  '5ad3ad61604f3c001a3fec10': 'Viking incursions',
#  '56dde1d966d3e219004dad8d': '',
#  '56dde27d9a695914005b9651': '',
#  '56de10b44396321400ee2595': 'Turkish',
#  '5ad3e96b604f3c001a3ff68c': 'upper Euphrates valley in northern Syria',
#  '56de11154396321400ee25aa': '',
#  '5ad3ea79604f3c001a3ff6e9': 'Byzantine Greece',
#  '56de15dbcffd8e1900b4b5c8': 'King Ethelred II of England',
#  '56de15dbcffd8e1900b4b5c9': 'Duke Richard II of Normandy',
#  '56de16ca4396321400ee25c6': 'Duke William II of Normandy',
#  '5ad3f5b0604f3c001a3ff9ad': 'Geoffrey Chaucer',
#  '56de179dcffd8e1900b4b5db': 'Irish',
#  '56de179dcffd8e1900b4b5dc': 'Irish culture',
#  '5ad3fc41604f3c001a3ffb8f': 'Antioch',
#  '56de3ebc4396321400ee26e8': 'conquest of Jerusalem',
# ...

# %%
dataset_dict_subset = {key: dataset_dict[key] for key, value in mismatch_single_dict.items()}

# %% [markdown]
# #### Check subset

# %%
def check(string, sub_str): 
    string = evaluation.normalize_answer(string)
    sub_str = evaluation.normalize_answer(sub_str)
    if (string.find(sub_str) == -1): 
        return 0
    else: 
        return 1

# %%
count_subset_1=0
subset_match_dict_1 = {}
question_subset = []
for id, gold_answers in dataset_dict_subset.items():
    a_pred = mismatch_single_dict[id]
    
    if len(gold_answers)>0 and a_pred!='':
        if max(check(a, a_pred) for a in gold_answers) == 1:
            count_subset_1 += 1
            subset_match_dict_1[a_pred]=gold_answers
            question_subset.append((question_dict[id],a_pred, gold_answers))
print('Subset 1 :', count_subset_1)
# Out:
# Subset 1 : 316

# %%
question_subset
# Out:
# [('Who did the Normans team up with in Anatolia?',
#   'Turkish',
#   ['Turkish forces', 'Turkish forces', 'Turkish forces']),
#  ('What architecture type came after Norman in England?',
#   'Gothic',
#   ['Early Gothic', 'Early Gothic', 'Early Gothic']),
#  ('What measure of a computational problem broadly defines the inherent difficulty of the solution?',
#   'significant resources',
#   ['if its solution requires significant resources',
#    'its solution requires significant resources',
#    'if its solution requires significant resources']),
#  ('What method is used to intuitively assess or quantify the amount of resources required to solve a computational problem?',
#   'mathematical models',
#   ['mathematical models of computation',
#    'mathematical models of computation',
#    'mathematical models of computation']),
#  ('What unit is measured to determine circuit complexity?',
#   'gates',
#   ['number of gates in a circuit',
#    'number of gates in a circuit',
# ...

# %%
count_subset_2=0
subset_match_dict_2 = {}
question_subset_2 = []
for id, gold_answers in dataset_dict_subset.items():
    a_pred = mismatch_single_dict[id]
    
    if len(gold_answers)>0 and a_pred!='':
        if max(check(a_pred, a) for a in gold_answers) == 1:
            count_subset_2 += 1
            subset_match_dict_2[a_pred]=gold_answers
            question_subset_2.append((question_dict[id],a_pred, gold_answers))
print('Subset 2 :', count_subset_2)
# Out:
# Subset 2 : 173

# %%
question_subset_2
# Out:
# [('Who ruled the duchy of Normandy',
#   'Richard I of Normandy',
#   ['Richard I', 'Richard I', 'Richard I']),
#  ('What river originally bounded the Duchy',
#   'river Epte',
#   ['Seine', 'Epte', 'Seine']),
#  ('Who did Emma Marry?',
#   'King Ethelred II of England',
#   ['King Ethelred II', 'Ethelred II', 'King Ethelred II']),
#  ("Who was Emma's brother?",
#   'Duke Richard II of Normandy',
#   ['Duke Richard II', 'Duke Richard II', 'Duke Richard II']),
#  ('Who killed Harold II? ',
#   'Duke William II of Normandy',
#   ['William II', 'Duke William II', 'Duke William II']),
#  ('What culture did the Normans combine with in Ireland?',
#   'Irish culture',
#   ['Irish', 'Irish', 'Irish']),
#  ('What major conquest did Tancred play a roll in?',
#   'conquest of Jerusalem',
#   ['Jerusalem', 'Jerusalem', 'Jerusalem']),
#  ('Who bought the rights?',
#   'Enrique Pérez de Guzmán, 2nd Count de Niebla',
#   ['Enrique Pérez de Guzmán',
#    'Enrique Pérez de Guzmán',
# ...

# %%
173*100/len(dataset_dict)
# Out:
# 1.45708750947528

# %%
from knockknock import slack_sender
webhook_url = "https://hooks.slack.com/services/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"
channel_name = "Get Notifications"

# %%
@slack_sender(webhook_url=webhook_url, channel=channel_name)
def add(a,b):
    print('Adding ...')
    c = a+b
    return c # Optional return value

# %%
add(1,1)
# Out:
# Adding ...
# 2
